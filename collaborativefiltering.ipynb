# %% [markdown]
# # Project Overview:
# Goal: Further personalizing book recommendations!
# What we need to achieve this:
# - Users with similar taste in books
# - A way to predict what we'll like based on what they like.

# %% [markdown]
# # Sources:
# Goodreads Book Data
# - Scraped by UCSD researchers!
# Available at: https://sites.google.com/eng.ucsd.edu/ucsdbookgraph/home

# %% [markdown]
# ## Some new files:
#
# books_titles.json:
# - for every book this has the title, url, url to cover image, as well as ratings received on GoodReads

# %% [markdown]
# # Project Steps
# 1. Find similar users
# 2. Create matrix
# 3. Recommend Books

# %% [markdown]
# # Reading in Books we like:

# %%
import pandas as pd

my_books = pd.read_csv("liked_books.csv", index_col=0)

# %%
my_books
# Out:
#      user_id   book_id  rating  \
# 0         -1   2517439       5
# 1         -1    113576       5
# 2         -1     35100       5
# 3         -1    228221       5
# 5         -1  17662739       5
# 6         -1    356824       5
# 7         -1  12125412       5
# 8         -1    139069       5
# 10        -1     76680       5
# 11        -1      1898       5
# 12        -1   5096865       5
# 13        -1    228665       5
# 17        -1    437143       5
# 18        -1  18949861       5
# 19        -1   2913377       5
# 20        -1   1215032       5
# 21        -1    883438       5
# 22        -1   5578108       5
# 23        -1    128029       5
# 24        -1     77203       5
# 25        -1      5439       5
# 26        -1   1685995       5
# 27        -1   6448772       5
# 527       -1   8161140       1
# 528       -1     28187       1
# 531       -1  25659450       1
# 532       -1     82599       1
#
#                                                  title
# 0               The Forever War  (The Forever War, #1)
# 1    The Smartest Guys in the Room: The Amazing Ris...
# 2                                Battle Cry of Freedom
# 3                                  The Mask of Command
# 5           2001: A Space Odyssey  (Space Odyssey, #1)
# 6    India After Gandhi: The History of the World's...
# 7      The Lady or the Tiger?: and Other Logic Puzzles
# 8            Endurance: Shackleton's Incredible Voyage
# 10                        Foundation  (Foundation, #1)
# 11   Into Thin Air: A Personal Account of the Mount...
# 12                                       In Cold Blood
# 13       The Eye of the World  (The Wheel of Time, #1)
# 17                A Short History of Nearly Everything
# 18                                             Contact
# 19   The Name of the Wind  (The Kingkiller Chronicl...
# 20   The Wise Man's Fear  (The Kingkiller Chronicle...
# 21                                        East of Eden
# 22   From Colony to Superpower: U.S. Foreign Relati...
# 23                            A Thousand Splendid Suns
# 24                                     The Kite Runner
# 25                             Interpreter of Maladies
# 26                                     Dune  (Dune #1)
# 27   Quantum: Einstein, Bohr, and the Great Debate ...
# 527                                       On the Beach
# 528  The Lightning Thief  (Percy Jackson and the Ol...
# 531                                          Arkwright
# 532                                   Rabbits: A Novel

# %%
my_books["book_id"] = my_books["book_id"].astype(str)

# %% [markdown]
# # Finding Similar Users
#
# We need to load in the mapping file.

# %%
# !head book_id_map.csv
# Out:
# book_id_csv,book_id
# 0,34684622
# 1,34536488
# 2,34017076
# 3,71730
# 4,30422361
# 5,33503613
# 6,33517540
# 7,34467031
# 8,6383669

# %%
csv_book_mapping = {}

with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
book_set = set(my_books["book_id"])

# %%
# !head goodreads_interactions.csv
# Out:
# user_id,book_id,is_read,rating,is_reviewed
# 0,948,1,5,0
# 0,947,1,5,1
# 0,946,1,5,0
# 0,945,1,5,0
# 0,944,1,5,0
# 0,943,1,5,0
# 0,942,1,5,0
# 0,941,1,5,0
# 0,940,1,5,0

# %%
# Lots of copying with Pandas, so working with it line by line helps with computer storage since it's too big. 
# !wc -l goodreads_interactions.csv
# Out:
#  228648343 goodreads_interactions.csv

# %%
# Dictionary, the keys will be the 
overlap_users = {}

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
            
        user_id, csv_id, _, rating, _ = line.split(",") # _ means we dont care about the variable (as much)

        book_id = csv_book_mapping.get(csv_id) # We have csv_id but we want the book_id !

        # if this is in our liked_books DF, lets add this user to our overlap_users dict. 
        # Keeping count how many times a given user has that overlaps with the books we like. 
        if book_id in book_set:
            if user_id not in overlap_users:
                overlap_users[user_id] = 1
            else:
                overlap_users[user_id] += 1

# %%
len(overlap_users)
# Out:
# 316341

# %%
# We only want to find users who have read some of the same books as us. Users who don't have the same 
# won't be useful for our model. List comprehension implemented below. So at least 20% of our book count. 
filtered_overlap_users = set([k for k in overlap_users if overlap_users[k] > my_books.shape[0]/5])

# %% [markdown]
# # Finding Similar User Book Ratings

# %%
# Now that we have a small set of users:
# Creating a list of all the books they've read, because we might want to read those same books.
interactions_list = []

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in filtered_overlap_users:
            book_id = csv_book_mapping[csv_id]
            interactions_list.append([user_id, book_id, rating])

# %% [markdown]
# # Creating a User/Book Matrix
#
# We are creating a user/book matrix in which ever row will be a different user and every column will be a different book. The cells will contain the rating that the user gave that book. If we have a ton of users+books, this matrix can easily become huge, hence our filtered set of users!

# %%
# how long is our interaction list?
len(interactions_list)
# Out:
# 5638701

# %%
# Looking at the first item, user_id, book_id, rating!
interactions_list[0]
# Out:
# ['282', '627206', '4']

# %%
# Turning it into a DataFrame!
interactions = pd.DataFrame(interactions_list, columns=["user_id", "book_id", "rating"])

# %%
# Add our own ratings to this matrix. 
interactions = pd.concat([my_books[["user_id", "book_id", "rating"]], interactions])

# %%
interactions
# Out:
#         user_id   book_id rating
# 0            -1   2517439      5
# 1            -1    113576      5
# 2            -1     35100      5
# 3            -1    228221      5
# 5            -1  17662739      5
# ...         ...       ...    ...
# 5638696  804100    475178      0
# 5638697  804100    186074      0
# 5638698  804100    153008      0
# 5638699  804100     45107      0
# 5638700  804100   1762198      5
#
# [5638728 rows x 3 columns]

# %%
interactions["book_id"] = interactions["book_id"].astype(str)
interactions["user_id"] = interactions["user_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"])

# %%
interactions["user_id"].unique()
# Out:
# array(['-1', '282', '874', ..., '442043', '712588', '804100'],
#       dtype=object)

# %%
interactions["user_index"] = interactions["user_id"].astype("category").cat.codes

# %%
len(interactions["user_index"].unique())
# Out:
# 1259

# %%
interactions["book_index"] = interactions["book_id"].astype("category").cat.codes

# %%
len(interactions["book_index"].unique())
# Out:
# 802870

# %%
1259 * 802870
# Out:
# 1010813330

# %% [markdown]
# # The Structure of the matrix:
# user_id converts to a user position.
#
# - We will be using a Sparse matrix.
#
# When we multiple our unique users and books we get 1010813330. Thats 1010813330 unique matrix cells, and if we tried to store all of that in a disk in a dense matrix, putting a value in each of those 1010813330 cells, it would take a huge amount of memory. Instead, we use a spare matrix, which is a little harder to work with but if there is no value in that column, we just leave it blank (taking up no storage or memory). If we work in Pandas or NumPy, we tend to work with dense matrices, so we will be creating a sparse matrix to save memory!

# %%
from scipy.sparse import coo_matrix

ratings_mat_coo = coo_matrix((interactions["rating"], (interactions["user_index"], interactions["book_index"])))

# %%
ratings_mat_coo
# Out:
# <1259x802870 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5638728 stored elements in COOrdinate format>

# %%
ratings_mat = ratings_mat_coo.tocsr()

# %% [markdown]
# # Finding Users Similar to Us

# %%
# -1 is us! Let's change that to my_index to know that's us. 
interactions[interactions["user_id"] == "-1"]
# Out:
#     user_id   book_id  rating  user_index  book_index
# 0        -1   2517439       5           0      414880
# 1        -1    113576       5           0       38971
# 2        -1     35100       5           0      575858
# 3        -1    228221       5           0      356004
# 5        -1  17662739       5           0      214285
# 6        -1    356824       5           0      581743
# 7        -1  12125412       5           0       59763
# 8        -1    139069       5           0      124430
# 10       -1     76680       5           0      722098
# 11       -1      1898       5           0      276178
# 12       -1   5096865       5           0      625929
# 13       -1    228665       5           0      357774
# 17       -1    437143       5           0      607659
# 18       -1  18949861       5           0      275433
# 19       -1   2913377       5           0      496223
# 20       -1   1215032       5           0       60398
# 21       -1    883438       5           0      767233
# 22       -1   5578108       5           0      637486
# 23       -1    128029       5           0       78172
# 24       -1     77203       5           0      724379
# 25       -1      5439       5           0      633999
# 26       -1   1685995       5           0      188133
# 27       -1   6448772       5           0      671711
# 527      -1   8161140       1           0      742532
# 528      -1     28187       1           0      480322
# 531      -1  25659450       1           0      431105
# 532      -1     82599       1           0      746448

# %%
my_index = 0

# %%
# Using cosine_similarity to quantify what users are similar to us. We are collaborating with other people in our data!
# Find similarity between two rows in our matrix. How similar is each user to us? 
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(ratings_mat[my_index,:], ratings_mat).flatten()

# %%
# how similar we are to ourselves:
similarity[0]
# Out:
# 0.9999999999999999

# %%
# Comparing to the next user:
similarity[1]
# Out:
# 0.04579825781910479

# %%
# We will find the indices of the users most similar to us in terms of book taste. The 15 users!
import numpy as np

indices = np.argpartition(similarity, -15)[-15:]

# %%
indices
# Out:
# array([1188,  942,  218,  129,  496,  435, 1208,  795, 1213, 1210, 1143,
#         321,  294,  862,    0])

# %%
# We need to find their user_id's: 
similar_users = interactions[interactions["user_index"].isin(indices)].copy()

# %%
# Taking ourselves out to not get self-recommendations:
similar_users = similar_users[similar_users["user_id"]!="-1"]

# %%
similar_users
# Out:
#         user_id   book_id  rating  user_index  book_index
# 45312      4133      5359       3         942      632143
# 45313      4133  10464963       4         942       13492
# 45314      4133      3858       3         942      593622
# 45315      4133  11827808       4         942       51904
# 45316      4133   7913305       4         942      732465
# ...         ...       ...     ...         ...         ...
# 5638521  712588  32388712       3        1143      543119
# 5638522  712588     16322       5        1143      183365
# 5638523  712588    860543       0        1143      759827
# 5638524  712588    853510       5        1143      756768
# 5638525  712588     13890       4        1143      124251
#
# [4302 rows x 5 columns]

# %% [markdown]
# # Creating Book Recommendations

# %%
# Let's figure out how many times each book appeared in these recommendations. Aggregating the rating count and the average rating.
book_recs = similar_users.groupby("book_id").rating.agg(['count', 'mean'])

# %%
book_recs
# Out:
#           count      mean
# book_id
# 1             6  3.833333
# 100322        1  0.000000
# 100365        1  0.000000
# 10046142      1  0.000000
# 1005          3  0.000000
# ...         ...       ...
# 99561         2  2.500000
# 99610         1  3.000000
# 99664         1  4.000000
# 9969571       3  2.333333
# 99944         1  0.000000
#
# [2856 rows x 2 columns]

# %%
# Hello old friend...we need the book titles :) We must ensure the book_id is a string. 
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

# %%
# Merging our two data sets! similar to SQL joins
book_recs = book_recs.merge(books_titles, how="inner", on="book_id")

# %%
book_recs
# Out:
#        book_id  count      mean  \
# 0            1      6  3.833333
# 1       100322      1  0.000000
# 2       100365      1  0.000000
# 3     10046142      1  0.000000
# 4         1005      3  0.000000
# ...        ...    ...       ...
# 2849     99561      2  2.500000
# 2850     99610      1  3.000000
# 2851     99664      1  4.000000
# 2852   9969571      3  2.333333
# 2853     99944      1  0.000000
#
#                                                   title  ratings  \
# 0     Harry Potter and the Half-Blood Prince (Harry ...  1713866
# 1                              Assata: An Autobiography    11057
# 2                                 The Mote in God's Eye    48736
# 3     Dancing in the Glory of Monsters: The Collapse...     2391
# 4                                   Think and Grow Rich    87634
# ...                                                 ...      ...
# 2849                                 Looking for Alaska   804587
# 2850                                The Best Laid Plans    17434
# 2851                                   The Painted Veil    24606
# 2852                                   Ready Player One   376328
# 2853                                  The Bhagavad Gita    33855
#
#                                                     url  \
# 0     https://www.goodreads.com/book/show/1.Harry_Po...
# 1     https://www.goodreads.com/book/show/100322.Assata
# 2     https://www.goodreads.com/book/show/100365.The...
# 3     https://www.goodreads.com/book/show/10046142-d...
# 4     https://www.goodreads.com/book/show/1005.Think...
# ...                                                 ...
# 2849  https://www.goodreads.com/book/show/99561.Look...
# 2850  https://www.goodreads.com/book/show/99610.The_...
# 2851  https://www.goodreads.com/book/show/99664.The_...
# 2852  https://www.goodreads.com/book/show/9969571-re...
# 2853  https://www.goodreads.com/book/show/99944.The_...
#
#                                             cover_image  \
# 0     https://images.gr-assets.com/books/1361039191m...
# 1     https://images.gr-assets.com/books/1328857268m...
# 2     https://images.gr-assets.com/books/1399490037m...
# 3     https://images.gr-assets.com/books/1328757755m...
# 4     https://s.gr-assets.com/assets/nophoto/book/11...
# ...                                                 ...
# 2849  https://images.gr-assets.com/books/1394798630m...
# 2850  https://images.gr-assets.com/books/1353374848m...
# 2851  https://images.gr-assets.com/books/1320421719m...
# 2852  https://images.gr-assets.com/books/1500930947m...
# 2853  https://images.gr-assets.com/books/1383059639m...
#
#                                               mod_title
# 0     harry potter and the halfblood prince harry po...
# 1                               assata an autobiography
# 2                                  the mote in gods eye
# 3     dancing in the glory of monsters the collapse ...
# 4                                   think and grow rich
# ...                                                 ...
# 2849                                 looking for alaska
# 2850                                the best laid plans
# 2851                                   the painted veil
# 2852                                   ready player one
# 2853                                  the bhagavad gita
#
# [2854 rows x 8 columns]

# %% [markdown]
# # Ranking Our Book Recommendations

# %%
# Normalizing the book count. We want to find the books specific to us and users like us! Not books super popular to everyone, we want recs adjusted to our taste.
book_recs["adjusted_count"] = book_recs["count"] * (book_recs["count"] / book_recs["ratings"])

# %%
#Score indicating how much we might like the book. Mean from all the users like us that read the same books as us. 
book_recs["score"] = book_recs["mean"] * book_recs["adjusted_count"]

# %%
# Taking out any books we already read. 
book_recs = book_recs[~book_recs["book_id"].isin(my_books["book_id"])]

# %%
# Take out any book titles that match a book we already read. A challenge with this data is that it's not entirely clean, some books have duplicate IDs. 
my_books["mod_title"] = my_books["title"].str.replace("[^a-zA-Z0-9 ]", "", regex=True).str.lower()

# %%
# Replace sequences of spaces with a single space
my_books["mod_title"] = my_books["mod_title"].str.replace("\s+", " ", regex=True)

# %%
# Take out anythng in our recs where the mod_title fits into the books we already read. Remove any of the books we already liked or read from recommendations. 
book_recs = book_recs[~book_recs["mod_title"].isin(my_books["mod_title"])]

# %%
# At least 3 similar users had to read it and like it in order for it to get on our recommendations. 
book_recs = book_recs[book_recs["count"]>2]

# %%
# Mean rating must be over 4. 
book_recs = book_recs[book_recs["mean"]>=4]

# %%
# Sort based on score. 
top_recs = book_recs.sort_values("mean", ascending=False)

# %%
top_recs
# Out:
#        book_id  count      mean  \
# 2265     62291      5  4.800000
# 600     157993      3  4.333333
# 1103     22034      3  4.333333
# 1176   2318271      3  4.333333
# 1909      4381      3  4.333333
# 243     119322      4  4.250000
# 1444   2767793      4  4.250000
# 2563     78983      4  4.250000
# 244     119324      3  4.000000
# 398      13497      4  4.000000
# 437     136251      6  4.000000
# 663   16181775      3  4.000000
# 2548     78508      3  4.000000
# 2549    785454      3  4.000000
# 2732    902715      3  4.000000
# 2781    944076      3  4.000000
#
#                                                   title  ratings  \
# 2265     A Storm of Swords (A Song of Ice and Fire, #3)   477834
# 600                                   The Little Prince   763309
# 1103                                      The Godfather   259150
# 1176                                   The Last Lecture   245804
# 1909                                     Fahrenheit 451   591506
# 243         The Golden Compass (His Dark Materials, #1)   973154
# 1444                    The Hero of Ages (Mistborn, #3)   149260
# 2563                  Kane and Abel (Kane and Abel, #1)    75215
# 244           The Subtle Knife (His Dark Materials, #2)   246697
# 398      A Feast for Crows (A Song of Ice and Fire, #4)   437398
# 437   Harry Potter and the Deathly Hallows (Harry Po...  1784684
# 663                 The Rosie Project (Don Tillman, #1)   259734
# 2548  The River of Doubt: Theodore Roosevelt's Darke...    32479
# 2549                                  Train to Pakistan    12993
# 2732         Before They Are Hanged (The First Law, #2)    70642
# 2781         Last Argument of Kings (The First Law, #3)    66986
#
#                                                     url  \
# 2265  https://www.goodreads.com/book/show/62291.A_St...
# 600   https://www.goodreads.com/book/show/157993.The...
# 1103  https://www.goodreads.com/book/show/22034.The_...
# 1176  https://www.goodreads.com/book/show/2318271.Th...
# 1909  https://www.goodreads.com/book/show/4381.Fahre...
# 243   https://www.goodreads.com/book/show/119322.The...
# 1444  https://www.goodreads.com/book/show/2767793-th...
# 2563  https://www.goodreads.com/book/show/78983.Kane...
# 244   https://www.goodreads.com/book/show/119324.The...
# 398   https://www.goodreads.com/book/show/13497.A_Fe...
# 437   https://www.goodreads.com/book/show/136251.Har...
# 663   https://www.goodreads.com/book/show/16181775-t...
# 2548  https://www.goodreads.com/book/show/78508.The_...
# 2549  https://www.goodreads.com/book/show/785454.Tra...
# 2732  https://www.goodreads.com/book/show/902715.Bef...
# 2781  https://www.goodreads.com/book/show/944076.Las...
#
#                                             cover_image  \
# 2265  https://images.gr-assets.com/books/1497931121m...
# 600   https://images.gr-assets.com/books/1367545443m...
# 1103  https://images.gr-assets.com/books/1394988109m...
# 1176  https://images.gr-assets.com/books/1388075896m...
# 1909  https://images.gr-assets.com/books/1351643740m...
# 243   https://images.gr-assets.com/books/1505766203m...
# 1444  https://images.gr-assets.com/books/1480717763m...
# 2563  https://s.gr-assets.com/assets/nophoto/book/11...
# 244   https://images.gr-assets.com/books/1505766360m...
# 398   https://images.gr-assets.com/books/1429538615m...
# 437   https://images.gr-assets.com/books/1474171184m...
# 663   https://images.gr-assets.com/books/1371651741m...
# 2548  https://images.gr-assets.com/books/1430014768m...
# 2549  https://images.gr-assets.com/books/1342220976m...
# 2732  https://s.gr-assets.com/assets/nophoto/book/11...
# 2781  https://images.gr-assets.com/books/1302062699m...
#
#                                               mod_title  adjusted_count  \
# 2265         a storm of swords a song of ice and fire 3        0.000052
# 600                                   the little prince        0.000012
# 1103                                      the godfather        0.000035
# 1176                                   the last lecture        0.000037
# 1909                                     fahrenheit 451        0.000015
# 243             the golden compass his dark materials 1        0.000016
# 1444                        the hero of ages mistborn 3        0.000107
# 2563                      kane and abel kane and abel 1        0.000213
# 244               the subtle knife his dark materials 2        0.000036
# 398          a feast for crows a song of ice and fire 4        0.000037
# 437   harry potter and the deathly hallows harry pot...        0.000020
# 663                     the rosie project don tillman 1        0.000035
# 2548  the river of doubt theodore roosevelts darkest...        0.000277
# 2549                                  train to pakistan        0.000693
# 2732             before they are hanged the first law 2        0.000127
# 2781             last argument of kings the first law 3        0.000134
#
#          score
# 2265  0.000251
# 600   0.000051
# 1103  0.000150
# 1176  0.000159
# 1909  0.000066
# 243   0.000070
# 1444  0.000456
# 2563  0.000904
# 244   0.000146
# 398   0.000146
# 437   0.000081
# 663   0.000139
# 2548  0.001108
# 2549  0.002771
# 2732  0.000510
# 2781  0.000537

# %% [markdown]
# # Improve the Display of the Books

# %%
# Like in the search notebook! :D 
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
    return '<img src="{}" width=50></img>'.format(val)

# %%
top_recs.style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_47bc6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >book_id</th>
#       <th class="col_heading level0 col1" >count</th>
#       <th class="col_heading level0 col2" >mean</th>
#       <th class="col_heading level0 col3" >title</th>
#       <th class="col_heading level0 col4" >ratings</th>
#       <th class="col_heading level0 col5" >url</th>
#       <th class="col_heading level0 col6" >cover_image</th>
#       <th class="col_heading level0 col7" >mod_title</th>
#       <th class="col_heading level0 col8" >adjusted_count</th>
#       <th class="col_heading level0 col9" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47bc6_level0_row0" class="row_heading level0 row0" >2265</th>
#       <td id="T_47bc6_row0_col0" class="data row0 col0" >62291</td>
#       <td id="T_47bc6_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_47bc6_row0_col2" class="data row0 col2" >4.800000</td>
#       <td id="T_47bc6_row0_col3" class="data row0 col3" >A Storm of Swords (A Song of Ice and Fire, #3)</td>
#       <td id="T_47bc6_row0_col4" class="data row0 col4" >477834</td>
#       <td id="T_47bc6_row0_col5" class="data row0 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/62291.A_Storm_of_Swords">Goodreads</a></td>
#       <td id="T_47bc6_row0_col6" class="data row0 col6" ><img src="https://images.gr-assets.com/books/1497931121m/62291.jpg" width=50></img></td>
#       <td id="T_47bc6_row0_col7" class="data row0 col7" >a storm of swords a song of ice and fire 3</td>
#       <td id="T_47bc6_row0_col8" class="data row0 col8" >0.000052</td>
#       <td id="T_47bc6_row0_col9" class="data row0 col9" >0.000251</td>
#     </tr>
#     <tr>
#       <th id="T_47bc6_level0_row1" class="row_heading level0 row1" >600</th>
#       <td id="T_47bc6_row1_col0" class="data row1 col0" >157993</td>
#       <td id="T_47bc6_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_47bc6_row1_col2" class="data row1 col2" >4.333333</td>
#       <td id="T_47bc6_row1_col3" class="data row1 col3" >The Little Prince</td>
#       <td id="T_47bc6_row1_col4" class="data row1 col4" >763309</td>
#       <td id="T_47bc6_row1_col5" class="data row1 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/157993.The_Little_Prince">Goodreads</a></td>
#       <td id="T_47bc6_row1_col6" class="data row1 col6" ><img src="https://images.gr-assets.com/books/1367545443m/157993.jpg" width=50></img></td>
#       <td id="T_47bc6_row1_col7" class="data row1 col7" >the little prince</td>
#       <td id="T_47bc6_row1_col8" class="data row1 col8" >0.000012</td>
#       <td id="T_47bc6_row1_col9" class="data row1 col9" >0.000051</td>
#     </tr>
#     <tr>
#       <th id="T_47bc6_level0_row2" class="row_heading level0 row2" >1103</th>
#       <td id="T_47bc6_row2_col0" class="data row2 col0" >22034</td>
#       <td id="T_47bc6_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_47bc6_row2_col2" class="data row2 col2" >4.333333</td>
#       <td id="T_47bc6_row2_col3" class="data row2 col3" >The Godfather</td>
#       <td id="T_47bc6_row2_col4" class="data row2 col4" >259150</td>
#       <td id="T_47bc6_row2_col5" class="data row2 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/22034.The_Godfather">Goodreads</a></td>
#       <td id="T_47bc6_row2_col6" class="data row2 col6" ><img src="https://images.gr-assets.com/books/1394988109m/22034.jpg" width=50></img></td>
#       <td id="T_47bc6_row2_col7" class="data row2 col7" >the godfather</td>
#       <td id="T_47bc6_row2_col8" class="data row2 col8" >0.000035</td>
#       <td id="T_47bc6_row2_col9" class="data row2 col9" >0.000150</td>
#     </tr>
#     <tr>
#       <th id="T_47bc6_level0_row3" class="row_heading level0 row3" >1176</th>
#       <td id="T_47bc6_row3_col0" class="data row3 col0" >2318271</td>
#       <td id="T_47bc6_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_47bc6_row3_col2" class="data row3 col2" >4.333333</td>
#       <td id="T_47bc6_row3_col3" class="data row3 col3" >The Last Lecture</td>
#       <td id="T_47bc6_row3_col4" class="data row3 col4" >245804</td>
#       <td id="T_47bc6_row3_col5" class="data row3 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2318271.The_Last_Lecture">Goodreads</a></td>
#       <td id="T_47bc6_row3_col6" class="data row3 col6" ><img src="https://images.gr-assets.com/books/1388075896m/2318271.jpg" width=50></img></td>
#       <td id="T_47bc6_row3_col7" class="data row3 col7" >the last lecture</td>
#       <td id="T_47bc6_row3_col8" class="data row3 col8" >0.000037</td>
#       <td id="T_47bc6_row3_col9" class="data row3 col9" >0.000159</td>
#     </tr>
#     <tr>
#       <th id="T_47bc6_level0_row4" class="row_heading level0 row4" >1909</th>
#       <td id="T_47bc6_row4_col0" class="data row4 col0" >4381</td>
#       <td id="T_47bc6_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_47bc6_row4_col2" class="data row4 col2" >4.333333</td>
#       <td id="T_47bc6_row4_col3" class="data row4 col3" >Fahrenheit 451</td>
#       <td id="T_47bc6_row4_col4" class="data row4 col4" >591506</td>
#       <td id="T_47bc6_row4_col5" class="data row4 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/4381.Fahrenheit_451">Goodreads</a></td>
#       <td id="T_47bc6_row4_col6" class="data row4 col6" ><img src="https://images.gr-assets.com/books/1351643740m/4381.jpg" width=50></img></td>
#       <td id="T_47bc6_row4_col7" class="data row4 col7" >fahrenheit 451</td>
#       <td id="T_47bc6_row4_col8" class="data row4 col8" >0.000015</td>
#       <td id="T_47bc6_row4_col9" class="data row4 col9" >0.000066</td>
#     </tr>
#     <tr>
#       <th id="T_47bc6_level0_row5" class="row_heading level0 row5" >243</th>
#       <td id="T_47bc6_row5_col0" class="data row5 col0" >119322</td>
#       <td id="T_47bc6_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_47bc6_row5_col2" class="data row5 col2" >4.250000</td>
#       <td id="T_47bc6_row5_col3" class="data row5 col3" >The Golden Compass (His Dark Materials, #1)</td>
#       <td id="T_47bc6_row5_col4" class="data row5 col4" >973154</td>
#       <td id="T_47bc6_row5_col5" class="data row5 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/119322.The_Golden_Compass">Goodreads</a></td>
#       <td id="T_47bc6_row5_col6" class="data row5 col6" ><img src="https://images.gr-assets.com/books/1505766203m/119322.jpg" width=50></img></td>
#       <td id="T_47bc6_row5_col7" class="data row5 col7" >the golden compass his dark materials 1</td>
#       <td id="T_47bc6_row5_col8" class="data row5 col8" >0.000016</td>
#       <td id="T_47bc6_row5_col9" class="data row5 col9" >0.000070</td>
#     </tr>
#     <tr>
#       <th id="T_47bc6_level0_row6" class="row_heading level0 row6" >1444</th>
#       <td id="T_47bc6_row6_col0" class="data row6 col0" >2767793</td>
#       <td id="T_47bc6_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_47bc6_row6_col2" class="data row6 col2" >4.250000</td>
#       <td id="T_47bc6_row6_col3" class="data row6 col3" >The Hero of Ages (Mistborn, #3)</td>
#       <td id="T_47bc6_row6_col4" class="data row6 col4" >149260</td>
#       <td id="T_47bc6_row6_col5" class="data row6 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2767793-the-hero-of-ages">Goodreads</a></td>
#       <td id="T_47bc6_row6_col6" class="data row6 col6" ><img src="https://images.gr-assets.com/books/1480717763m/2767793.jpg" width=50></img></td>
#       <td id="T_47bc6_row6_col7" class="data row6 col7" >the hero of ages mistborn 3</td>
#       <td id="T_47bc6_row6_col8" class="data row6 col8" >0.000107</td>
#       <td id="T_47bc6_row6_col9" class="data row6 col9" >0.000456</td>
#     </tr>
#     <tr>
#       <th id="T_47bc6_level0_row7" class="row_heading level0 row7" >2563</th>
#       <td id="T_47bc6_row7_col0" class="data row7 col0" >78983</td>
#       <td id="T_47bc6_row7_col1" class="data row7 col1" >4</td>
#       <td id="T_47bc6_row7_col2" class="data row7 col2" >4.250000</td>
#       <td id="T_47bc6_row7_col3"

# %% [markdown]
# The adjusted_count and score columns show us how they are rated in terms of recommendations for next books we might want to read!

# %% [markdown]
# # Potential Next Steps:

# %% [markdown]
# 1. Play around with some of the filters, such as filtered_overlap_users.
# 2. Other ways to scrap GoodReads are available!
# 3. In similarity we could change the 15 user limit.
# 4. We can also tweak the score during the book recommendations and what books we choose to remove from the set (ex/ does it have to be a 4 star rating? Could it be less than 3 people?)
